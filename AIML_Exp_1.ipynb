# %% [markdown]
# <a href="https://colab.research.google.com/github/kruthikroshan/AIML_2303A52339/blob/main/AIML_Exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1 – Implement Basic Data Structures using Numpy, Pandas
# bold text

# %% [markdown]
# Lists
#
# Arrays
#
# Identify their type using type()

# %%
import numpy as np
l1 = [1,5,6]
ar1 = np.array(l1)
ar1
# Out:
# array([1, 5, 6])

# %%
type(l1)
# Out:
# list

# %%
type(ar1)
# Out:
# numpy.ndarray

# %% [markdown]
# Perform mathematical operations on these datasets created - multiplication, division, powerof

# %%
ar2 = np.array([3,4,8])
ar2
# Out:
# array([3, 4, 8])

# %%
print("ar2 multiplied by ar1: ",ar2*ar1)
print("ar2 divided by ar1: ", ar2/ar1)
print("ar2 raised to the power of ar1: ",ar2**ar1)
# Out:
# ar2 multiplied by ar1:  [ 3 20 48]
# ar2 divided by ar1:  [3.         0.8        1.33333333]
# ar2 raised to the power of ar1:  [     3   1024 262144]

# %% [markdown]
# Combine text with Numpy fuction to generate a textual output - "Addition of Two: array1 +array 2"

# %%
print('array1 added to array2: ',ar1+ar2)
print("Adding two numpy arrays {array1} and {array2} together:", ar1+ar2)
print(f"Adding two numpy arrays {ar1} and {ar2} together: {ar1+ar2}")
# Out:
# array1 added to array2:  [ 4  9 14]
# Adding two numpy arrays {array1} and {array2} together: [ 4  9 14]
# Adding two numpy arrays [1 5 6] and [3 4 8] together: [ 4  9 14]

# %% [markdown]
# Implementing np.sin(), log(), log2(), np.exp()

# %%
# Sine function
print('sine of ar1: ',np.sin(ar1))

# Logirithm function
print("Natural logarithm: ",np.log(ar1))
print("Base-10 logarithm: ",np.log10(ar2))
print("Base-2 logarithm: ",np.log2(ar1))

# Exponential function
print('Exponential: ',np.exp(ar2))
# Out:
# sine of ar1:  [ 0.84147098 -0.95892427 -0.2794155 ]
# Natural logarithm:  [0.         1.60943791 1.79175947]
# Base-10 logarithm:  [0.47712125 0.60205999 0.90308999]
# Base-2 logarithm:  [0.         2.32192809 2.5849625 ]
# Exponential:  [  20.08553692   54.59815003 2980.95798704]

# %% [markdown]
# Part 2 – Visualization of Data using matplotlib, pyplots Packages

# %% [markdown]
# Generate Scatter Plot

# %% [markdown]
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.

# %%
people = ['Arun','Barath','Chen','Dhoni','Emily','Farook',
          'Gagan','Hero','Root','Julio','Virat','Lily']
age = [23,15,42,24,33,20,34,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(weight,height)
plt.title('Relationship between Weight and Height of Patients')
plt.ylabel('Height in Meters')
plt.xlabel('Weight of Patients in Kilograms')
plt.show()

# %% [markdown]
# Bar Chart Generation

# %%
plt.figure(figsize=(10,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='red',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Histogram Generation

# %%
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='indigo',edgecolor='white', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Pie Chart Generation

# %%
# creating pie char and Main plot function "pie"
fig = plt.figure(figsize=(6,6))
plt.pie(weight,labels=people)
plt.show()

# pd[['Age',
#     'weight',
#     'height']].plot.pie(subplots = True,
#                              legend= False,
#                              figsize =(6,6),)

# %% [markdown]
# Part 3 - Access Data from various sources and formats

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_table("/content/data.txt")

# %%
df1
# Out:
# Empty DataFrame
# Columns: [ hi Kruthik roshan]
# Index: []

# %%
# CSV file
df2 = pd.read_csv("/content/data (1) (1).csv")
df2
# Out:
#    ID       Name  Height (cm)  Weight (kg)
# 0   1      virat          175           70
# 1   2       raju          160           55
# 2   3    kruthik          170           65
# 3   4     roshan          180           85
# 4   5      omsri          165           60
# 5   6  saiposhan          185           90
# 6   7       siri          162           58
# 7   8       hari          172           72
# 8   9      vijay          168           66
# 9  10      rahul          177           74

# %%
# Excel file
df3 = pd.read_excel("/content/Untitled spreadsheet.xlsx")
df3
# Out:
#      ID  Age
# 0  2339   19
# 1  2252   20
# 2  2365   61
# 3  1527   13
# 4  5656   18
# 5  1625   20
